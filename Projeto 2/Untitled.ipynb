# %%
#================================== Imports ==============================
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import nltk
nltk.download('rslp')
stemmer = nltk.stem.RSLPStemmer()


#================================== Importa a planilha em uma variável ==============================
dados = pd.read_excel('tweets_certos_2.0.xlsx')

relevancia=[]
for avaliacao in dados["avaliacao"]:
    if avaliacao == 0 or avaliacao == 2:
        relevancia.append(1)
    else:
        relevancia.append(0)
        
dados["rel/irrel"]= relevancia

dados
# Out:
# [nltk_data] Downloading package rslp to /Users/Gustavo/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
#                                            Treinamento  avaliacao  rel/irrel
# 0                               me patrocinem @twitter          1          0
# 1    rt @claudeluca_: @canaltech que mané bolinha d...          0          1
# 2    @wereonlyadream @twitter ta pessimo, tem rt qu...          0          1
# 3    rt @andremcapanema: @luscas alguém avisa pra e...          2          1
# 4    amiga @twitter eu já entendi q vc é bilíngue h...          2          1
# 5    rt @robherrera1912: o @twitter até tentou. mas...          0          1
# 6    @canaltech oi @twitter se eu quisesse que aqui...          0          1
# 7    rt @rerodrigues001: @lfbadan @btrazzini @canal...          0          1
# 8    o torcedor mauro jr (@maucedo) abusou de entor...          2          1
# 9    @twitter @twittersupport meu anjo azul vc não ...          0          1
# 10   pode tudo menos mostrar se tá online ou não, c...          0          1
# 11   parabens pela coragem, porque noção não tem, n...          1          0
# 12   rt @rerodrigues001: @lfbadan @btrazzini @canal...          0          1
# 13   @reporte_indigo @fernandeznorona @twitter es d...          1          0
# 14   rt @lira_juu: o twitter com tanta coisa pra me...          0          1
# 15   @twitter não queremos, pode parar de frescura ...          0          1
# 16   @emillyaraujoof para mim twitter virou uma red...          0          1
# 17   @matiostriste @_bananaum @twitter eu num sei q...          2          1
# 18   rt @cesarfilho: na sua opinião, quem vence as ...          1          0
# 19   ah não @twitter @twitterbrasil eu imploro,por ...          0          1
# 20   siga-nos e mantenha-se sempre muito bem inform...          1          0
# 21             @super_league_gr @twitter bravo. 👏🏻👏🏻👏🏻          2          1
# 22   2018. o @twitter ainda não deixa baixar vídeos...          0          1
# 23   rt @rafatopog: mais uma vez. censuram um perfi...          0          1
# 24   @louis_tomlinson @harry_styles tirou dnv @twit...          0          1
# 25   @jinrisolji contra fatos não há argumentos amo...          0          1
# 26               @outraniviacomn @twitter forças ícone          2          1
# 27   vou começar a xingar muito no @twitter por cau...          2          1
# 28   @horionsys @twitter @twitterbrasil hahaha! tui...          2          1
# 29   rt @andremcapanema: @luscas alguém avisa pra e...          0          1
# ..                                                 ...        ...        ...
# 272  @flaviogordon o mais irritante é que as redes ...          0          1
# 273  @twitter migo, ngm tá gostando https://t.co/rr...          0          1
# 274  rt @andremcapanema: @luscas alguém avisa pra e...          0          1
# 275  rt @rafatopog: mais uma vez. censuram um perfi...          0          1
# 276  e editar as publicações @twitter https://t.co/...          1          0
# 277  rt @thaisycardoso: alô @twitter nós usamos twi...          2          1
# 278  @cesarfilho @carmen51399531 @twitter vote bols...          1          0
# 279  @twitter pelo amor de deus para https://t.co/l...          0          1
# 280  @luisandres_luce @laffertemarcela @lavinjoaqui...          1          0
# 281  @luscas @twitter a gente nao quer atualização....          2          1
# 282  @kl4u55 esse era o momento de ter áudio no twi...          0          1
# 283  rt @andremcapanema: @luscas alguém avisa pra e...          0          1
# 284  rt @srtalawyerbr17: assistimos a censura e a p...          1          0
# 285  rt @okikoloko: @canaltech sério!!! tem alguém ...          0          1
# 286  @cejbrasil @twitter na cabeça desses doentes s...          1          0
# 287  @anapzc e muita frescura ...... pq o @twitter ...          0          1
# 288          @ticosindim @twitter porque nós mataste ?          1          0
# 289  @dionatandiego11 @santosdfabio @gustavo0820631...          1          0
# 290  alguém já começou a criar um novo site pra sub...          0          1
# 291  #otwitternãoéfacebook e caso o @twitter não te...          2          1
# 292  rt @lfbadan: @canaltech @twitter entenda de um...          2          1
# 293  twitter agr vai mostrar qdo a gnt estiver onli...          0          1
# 294  @olamundo18 @acpneves @rogularte @robertagbett...          1          0
# 295  porra @twitter para de cagar aqui \ngostamos d...          0          1
# 296  rt @matiostriste: eu nem sei pq eu vou postar\...          0          1
# 297  ei @twitter eu tô clicando no canto da imagem ...          1          0
# 298  @cooperjoao @twitter meu tentaram hackear minh...          0          1
# 299  @ilovelanadelrey @sugar_rods @got7venarmy @can...          1          0
# 300                             me patrocinem @twitter          1          0
# 301  rt @claudeluca_: @canaltech que mané bolinha d...          0          1
#
# [302 rows x 3 columns]
